# %%
import pandas as pd

# %%
a=pd.read_csv("data.csv")
b=pd.read_csv("data1.csv")
c=pd.read_csv("data2.csv")
a.to_csv("data.csv",index=False)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       640 non-null    int64
#  1   chapter_verse    640 non-null    object
#  2   eng_def          640 non-null    object
#  3   eng_dict         640 non-null    object
#  4   eng_shloka       640 non-null    object
#  5   sanskrit_shloka  640 non-null    object
#  6   hindi_def        640 non-null    object
#  7   hindi_shloka     640 non-null    object
#  8   telugu_def       640 non-null    object
#  9   telugu_shloka    640 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 50.1+ KB

# %%
# Out:
#     chapter_verse                                            eng_def  \
# 0             1.1  Dhritarashtra said: O Sanjay, after gathering ...
# 1             1.2  Sanjay said: On observing the Pandava army sta...
# 2             1.3  Duryodhan said: Respected teacher!  Behold the...
# 3           1.4-6  Behold in their ranks are many powerful warrio...
# 4             1.7  O best of Brahmins, hear too about the princip...
# ..            ...                                                ...
# 635         18.74  Sanjay said: Thus, have I heard this wonderful...
# 636         18.75  By the grace of Veda Vyas, I have heard this s...
# 637         18.76  As I repeatedly recall this astonishing and wo...
# 638         18.77  And remembering that most astonishing and wond...
# 639         18.78  Wherever there is Shree Krishna, the Lord of a...
#
#                                               eng_dict  \
# 0    OrderedDict({'dhṛitarāśhtraḥ uvācha': 'Dhritar...
# 1    OrderedDict({'sanjayaḥ uvācha': 'Sanjay said',...
# 2    OrderedDict({'paśhya': 'behold', 'etām': 'this...
# 3    OrderedDict({'atra': 'here', 'śhūrāḥ': 'powerf...
# 4    OrderedDict({'asmākam': 'ours', 'tu': 'but', '...
# ..                                                 ...
# 635  OrderedDict({'sañjayaḥ uvācha': 'Sanjay said',...
# 636  OrderedDict({'vyāsa-prasādāt': 'by the grace o...
# 637  OrderedDict({'rājan': 'king', 'sansmṛitya sans...
# 638  OrderedDict({'tat': 'that', 'cha': 'and', 'san...
# 639  OrderedDict({'yatra': 'wherever', 'yoga-īśhvar...
#
#                                             eng_shloka  \
# 0    dhṛitarāśhtra uvācha \n  dharma-kṣhetre kuru-k...
# 1    sañjaya uvācha \n  dṛiṣhṭvā tu pāṇḍavānīkaṁ vy...
# 2    paśhyaitāṁ pāṇḍu-putrāṇām āchārya mahatīṁ cham...
# 3    atra śhūrā maheṣhvāsā bhīmārjuna-samā yudhi \n...
# 4    asmākaṁ tu viśhiṣhṭā ye tānnibodha dwijottama ...
# ..                                                 ...
# 635  sañjaya uvācha \n ity ahaṁ vāsudevasya pārthas...
# 636  vyāsa-prasādāch chhrutavān etad guhyam ahaṁ pa...
# 637  rājan sansmṛitya sansmṛitya saṁvādam imam adbh...
# 638  tach cha sansmṛitya sansmṛitya rūpam aty-adbhu...
# 639  यत्र योगश्वरः कृष्णो यत्र पार्थो धनुर्धरः।  \r...
#
#                                             telugu_def  \
# 0    ధృతరాష్ట్రుడు పలికెను: ఓ సంజయా, ధర్మభూమి అయిన ...
# 1    సంజయుడు పలికెను: సైనిక వ్యూహాత్మకంగా నిలిపి ఉన...
# 2    దుర్యోధనుడు అన్నాడు: గౌరవనీయులైన గురువర్యా! ద్...
# 3    వారి పక్షాన సైన్యంలో ఉన్న ఎంతోమంది శక్తివంతమైన...
# 4    ఓ బ్రాహ్మణోత్తమా, మన పక్షంలో ఉన్న ప్రధాన యోధుల...
# ..                                                 ...
# 635  సంజయుడు పలికెను: ఈ విధంగా నేను, వసుదేవుని పుత్...
# 636  వేదవ్యాసుని అనుగ్రహం చేత, నేను ఈ యొక్క సర్వోత్...
# 637  సర్వోత్కృష్ట శ్రీ కృష్ణ భగవానునకు మరియు అర్జున...
# 638  మరియు ఆ శ్రీ కృష్ణుడి అత్యద్భుతమైన మరియు ఆశ్చర...
# 639  ఎక్కడెక్కడైతే యోగేశ్వరుడైన శ్రీ కృష్ణుడు మరియు...
#
#                                          telugu_shloka
# 0    ధృతరాష్ట్ర ఉవాచ ।  \n  ధర్మక్షేత్రే కురుక్షేత్...
# 1    సంజయ ఉవాచ ।  \n  దృష్ట్వా తు పాండవానీకం వ్యూఢం...
# 2    పశ్యైతాం పాండుపుత్రాణామ్ ఆచార్య మహతీం చమూమ్ । ...
# 3    అత్ర శూరా మహేష్వాసా భీమార్జునసమా యుధి ।  \n  య...
# 4    అస్మాకం తు విశిష్టా యే తాన్నిబోధ ద్విజోత్తమ । ...
# ..                                                 ...
# 635  సంజయ ఉవాచ ।  \n  ఇత్యహం వాసుదేవస్య పార్థస్య చ ...
# 636  వ్యాసప్రసాదాఛ్చ్రుతవాన్ ఏతద్గుహ్యమహం పరమ్ ।  \...
# 637  రాజన్ సంస్మృత్య సంస్మృత్య సంవాదమిమమద్భుతమ్ ।  ...
# 638  తచ్చ సంస్మృత్య సంస్మృత్య రూపమత్యద్భుతం హరేః । ...
# 639  యత్ర యోగేశ్వరః కృష్ణో యత్ర పార్థో ధనుర్ధరః ।  ...
#
# [640 rows x 9 columns]

# %%
result.info()
result.to_csv("data.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   chapter_verse    640 non-null    object
#  1   eng_def          640 non-null    object
#  2   eng_dict         640 non-null    object
#  3   eng_shloka       640 non-null    object
#  4   sanskrit_shloka  640 non-null    object
#  5   hindi_def        640 non-null    object
#  6   hindi_shloka     640 non-null    object
#  7   telugu_def       640 non-null    object
#  8   telugu_shloka    640 non-null    object
# dtypes: object(9)
# memory usage: 45.1+ KB
